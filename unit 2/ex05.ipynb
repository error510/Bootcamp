# %%
import pandas as pd 
from matplotlib import * 
import math 
import numpy as np
import seaborn as sns

df = pd.read_csv('./diabetes.csv')
df.head()

# input + output = numerical 
# we filter the dataframe based on the correlation between variables

df_corr = df.corr()
df_map = sns.heatmap(df_corr,linewidths=1,linecolor='white',square=True,cmap="YlGnBu")
